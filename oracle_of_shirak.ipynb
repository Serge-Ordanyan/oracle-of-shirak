# %%
from datetime import datetime
import random

def oracle_prophecy():
    now = datetime.now()
    moon_phases = ["New Moon", "Waxing Crescent", "First Quarter", "Waxing Gibbous",
                   "Full Moon", "Waning Gibbous", "Last Quarter", "Waning Crescent"]
    moods = ["restless", "serene", "charged", "mournful", "curious", "watchful", "silent", "radiant"]
    omens = [
        "A shadow crosses your path — do not ignore it.",
        "The wind carries a forgotten name. Speak it aloud.",
        "A door will open, but not the one you expect.",
        "The stars blink twice when you lie.",
        "You are being watched — by memory, not by eyes."
    ]
    
    phase = random.choice(moon_phases)
    mood = random.choice(moods)
    omen = random.choice(omens)
    
    return f"""
🕯️ **Date**: {now.strftime('%A, %B %d, %Y')}
🌙 **Moon Phase**: {phase}
🧠 **Mood of the Cosmos**: {mood}
📜 **Prophecy**: {omen}
"""

print(oracle_prophecy())
# Out:
# 🕯️ **Date**: Thursday, November 06, 2025
# 🌙 **Moon Phase**: Waning Crescent
# 🧠 **Mood of the Cosmos**: silent
# 📜 **Prophecy**: A door will open, but not the one you expect.
