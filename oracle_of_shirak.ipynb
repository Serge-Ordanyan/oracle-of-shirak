# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "db8fd254-9c1e-4255-92bd-e050ee1ff093",
   "metadata": {},
   "outputs": [],
   "source": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "",
   "name": ""
  },
  "language_info": {
   "name": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
