# %%
from datetime import datetime
import random

def summon_oracle():
    now = datetime.now()
    prophecies = [
        "The moons align in your favor.",
        "Beware the shadow of your own ambition.",
        "A stranger brings unexpected wisdom.",
        "The stars whisper of a turning tide.",
        "Your silence will echo louder than words."
    ]
    return f"🕯️ On {now.strftime('%A, %B %d, %Y')}, the Oracle says: {random.choice(prophecies)}"

summon_oracle()
# Out:
# '🕯️ On Thursday, November 06, 2025, the Oracle says: A stranger brings unexpected wisdom.'
